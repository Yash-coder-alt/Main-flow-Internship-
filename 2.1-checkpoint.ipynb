# %%
###Manipulation of string

word = "Basics of Python!"
print("The word is:",word)
print("-----------------------------------------------------------------------------------------------------------------------------------------")
letter=word[5]
print("The letter is:",letter)
print("-----------------------------------------------------------------------------------------------------------------------------------------")
length=len(word)
print("The length of the string is:",length)
print("-----------------------------------------------------------------------------------------------------------------------------------------")
character="s"
print("The character is:",character)
position=word.find(character)
print("The position of the character in the string is:",position)
position=word.index(character)
print("The index of the character in the string is:",position)
print("-----------------------------------------------------------------------------------------------------------------------------------------")
character=" "
position=word.count(character)
print("The number of spaces in the string is:",position)
print("-----------------------------------------------------------------------------------------------------------------------------------------")
print (word[0]) #get one char of the word
print("-----------------------------------------------------------------------------------------------------------------------------------------")
print (word[0:3]) #get the first three char
print("-----------------------------------------------------------------------------------------------------------------------------------------")
print (word[-3:]) #get the last three char
print("-----------------------------------------------------------------------------------------------------------------------------------------")
print (word[3:]) #get all but the three first char
print("-----------------------------------------------------------------------------------------------------------------------------------------")
print (word[:-3]) #get all but the three last character
print("-----------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# The word is: Basics of Python!
# -----------------------------------------------------------------------------------------------------------------------------------------
# The letter is: s
# -----------------------------------------------------------------------------------------------------------------------------------------
# The length of the string is: 17
# -----------------------------------------------------------------------------------------------------------------------------------------
# The character is: s
# The position of the character in the string is: 2
# The index of the character in the string is: 2
# -----------------------------------------------------------------------------------------------------------------------------------------
# The number of spaces in the string is: 2
# -----------------------------------------------------------------------------------------------------------------------------------------
# B
# -----------------------------------------------------------------------------------------------------------------------------------------
# Bas
# -----------------------------------------------------------------------------------------------------------------------------------------
# Bas
# -----------------------------------------------------------------------------------------------------------------------------------------
# on!
# -----------------------------------------------------------------------------------------------------------------------------------------
# ics of Python!
# -----------------------------------------------------------------------------------------------------------------------------------------
# Basics of Pyth
# -----------------------------------------------------------------------------------------------------------------------------------------
